# %% [markdown]
# ### Install the Library

# %%
import requests
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ### SEC API

# %%
# create request header
headers = {'User-Agent': "aariyur@berkeley.edu"}

# %%
companyTickers = requests.get(
    "https://www.sec.gov/files/company_tickers.json",
    headers=headers
    )

# review response / keys
print(companyTickers.json().keys())

# %%
# format response to dictionary and get first key/value
firstEntry = companyTickers.json()['0']

# parse CIK // without leading zeros
directCik = companyTickers.json()['0']['cik_str']

# dictionary to dataframe
companyData = pd.DataFrame.from_dict(companyTickers.json(),
                                     orient='index')

# %%
# add leading zeros to CIK
companyData['cik_str'] = companyData['cik_str'].astype(
                           str).str.zfill(10)

# review data
print(companyData[:1])

cik = companyData[0:1].cik_str[0]

# get company specific filing metadata
filingMetadata = requests.get(
    f'https://data.sec.gov/submissions/CIK{cik}.json',
    headers=headers
    )

# review json 
print(filingMetadata.json().keys())
filingMetadata.json()['filings']
filingMetadata.json()['filings'].keys()
filingMetadata.json()['filings']['recent']
filingMetadata.json()['filings']['recent'].keys()

# %%
print(filings)
# Out:
# {'total': {'value': 256, 'relation': 'eq'}, 'query': {'from': 2, 'size': 102}, 'filings': [{'id': '9c2ff6f54d22aa52b1f1b50bcdf673ba', 'accessionNo': '0001321655-23-000011', 'cik': '1321655', 'ticker': 'PLTR', 'companyName': 'Palantir Technologies Inc.', 'companyNameLong': 'Palantir Technologies Inc. (Filer)', 'formType': '10-K', 'description': 'Form 10-K - Annual report [Section 13 and 15(d), not S-K Item 405]', 'filedAt': '2023-02-21T16:35:44-05:00', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1321655/000132165523000011/0001321655-23-000011.txt', 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1321655/000132165523000011/0001321655-23-000011-index.htm', 'linkToXbrl': '', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1321655/000132165523000011/pltr-20221231.htm', 'entities': [{'companyName': 'Palantir Technologies Inc. (Filer)', 'cik': '1321655', 'irsNo': '680551851', 'fiscalYearEnd': '1231', 'type': '10-K', 'act': '34', 'fileNo': '001-39540', 'filmN
# ...

# %%
import json

with open('filings.json', 'w') as f:
    json.dump(filings, f)

# %%
import json
import dict2xml

# Open the JSON file and load its content into a dictionary
# Specify the encoding of your JSON file (e.g. UTF-8)

# Convert the dictionary into an XML string
filings_xml = dict2xml.dict2xml(filings)

# Write the XML string to a new file
# Specify the encoding of your XML file (e.g. UTF-8)
with open('filings.xml', 'w', encoding='ISO-8859-1') as f:
    f.write(filings_xml)
